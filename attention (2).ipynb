# %% [markdown]
# Importing necessary Libraries

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# Collecting data from yfinance

# %%
infosys = yf.Ticker("INFY")
infosys.history(start='2023-01-01', end='2023-12-13',interval="1h", actions=False)
# Out:
#                                 Open       High        Low      Close   Volume
# Datetime
# 2023-01-03 09:30:00-05:00  18.180000  18.350000  18.120001  18.190001  1463614
# 2023-01-03 10:30:00-05:00  18.190001  18.250000  18.080000  18.184999  1952537
# 2023-01-03 11:30:00-05:00  18.184999  18.184999  18.084999  18.084999   923223
# 2023-01-03 12:30:00-05:00  18.084999  18.139999  18.055000  18.115000   673909
# 2023-01-03 13:30:00-05:00  18.110001  18.168501  18.100000  18.125000   706965
# ...                              ...        ...        ...        ...      ...
# 2023-12-12 11:30:00-05:00  17.500000  17.500000  17.480000  17.495001   241934
# 2023-12-12 12:30:00-05:00  17.490000  17.510000  17.485001  17.495001   328332
# 2023-12-12 13:30:00-05:00  17.500000  17.530001  17.495001  17.525000   660845
# 2023-12-12 14:30:00-05:00  17.530001  17.559999  17.500000  17.555000   829501
# 2023-12-12 15:30:00-05:00  17.555000  17.559999  17.530001  17.559999  1165116
#
# [1658 rows x 5 columns]

# %%
## EDA 
df=infosys.history(start='2023-01-01', end='2023-12-13',interval="1h", actions=False)
print(df.shape)
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
print("number of null values in each column", df.isnull().sum())
print("number of NaN values in each column", df.isna().sum())
# Out:
# (1658, 5)
#                                 Open       High        Low      Close   Volume
# Datetime
# 2023-01-03 09:30:00-05:00  18.180000  18.350000  18.120001  18.190001  1463614
# 2023-01-03 10:30:00-05:00  18.190001  18.250000  18.080000  18.184999  1952537
# 2023-01-03 11:30:00-05:00  18.184999  18.184999  18.084999  18.084999   923223
# 2023-01-03 12:30:00-05:00  18.084999  18.139999  18.055000  18.115000   673909
# 2023-01-03 13:30:00-05:00  18.110001  18.168501  18.100000  18.125000   706965
#                                 Open       High        Low      Close   Volume
# Datetime
# 2023-12-12 11:30:00-05:00  17.500000  17.500000  17.480000  17.495001   241934
# 2023-12-12 12:30:00-05:00  17.490000  17.510000  17.485001  17.495001   328332
# 2023-12-12 13:30:00-05:00  17.500000  17.530001  17.495001  17.525000   660845
# 2023-12-12 14:30:00-05:00  17.530001  17.559999  17.500000  17.555000   829501
# 2023-12-12 15:30:00-05:00  17.555000  17.559999  17.530001  17.559999  1165116
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1658 entries, 2023-01-03 09:30:00-05:00 to 2023-12-12 15:30:00-05:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1658 non-null   float64
#  1   High    1658 non-null   float64
#  2   Low     1658 non-null   float64
#  3   Close   1658 non-null   float64
#  4   Volume  1658 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 77.7 KB
# None
#               Open         High          Low        Close        Volume
# count  1658.000000  1658.000000  1658.000000  1658.000000  1.658000e+03
# mean     17.002096    17.044441    16.962312    17.004889  1.168997e+06
# std       1.139126     1.142198     1.136585     1.138733  9.682992e+05
# min      14.745700    14.780000    14.712000    14.750000  1.624040e+05
# 25%      16.151250    16.181250    16.091250    16.125000  5.917675e+05
# 50%      17.080000    17.132500    17.035000    17.082500  9.005575e+05
# 75%      17.787501    17.813750    17.740000    17.775000  1.454929e+06
# max      19.545000    19.590000    19.480000    19.545000  1.106724e+07
# number of null values in each column Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64
# number of NaN values in each column Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.to_csv("infosys.csv", index=True, index_label="Datetime")

# %%
df.head()
# Out:
#                                 Open       High        Low      Close   Volume
# Datetime
# 2023-01-03 09:30:00-05:00  18.180000  18.350000  18.120001  18.190001  1463614
# 2023-01-03 10:30:00-05:00  18.190001  18.250000  18.080000  18.184999  1952537
# 2023-01-03 11:30:00-05:00  18.184999  18.184999  18.084999  18.084999   923223
# 2023-01-03 12:30:00-05:00  18.084999  18.139999  18.055000  18.115000   673909
# 2023-01-03 13:30:00-05:00  18.110001  18.168501  18.100000  18.125000   706965

# %%
# taking only the close column
data = df[['Close']]
print(data.head())
# Out:
#                                Close
# Datetime
# 2023-01-03 09:30:00-05:00  18.190001
# 2023-01-03 10:30:00-05:00  18.184999
# 2023-01-03 11:30:00-05:00  18.084999
# 2023-01-03 12:30:00-05:00  18.115000
# 2023-01-03 13:30:00-05:00  18.125000

# %%
# plotting the data
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price INR', fontsize=18)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
class DataLoader():
   

    def __init__(self, filename,cols):
        dataframe = pd.read_csv(filename)
        self.data_train = dataframe.get(cols).values
        self.len_train  = len(self.data_train)
        self.len_train_windows = None

    def get_data(self, seq_len, normalise):
        '''
        Create x, y train data windows
        Warning: batch method, not generative, make sure you have enough memory to
        load data, otherwise use generate_training_window() method.
        '''
        data_x = []
        data_y = []
        for i in range(self.len_train - seq_len):
            x, y = self._next_window(i, seq_len, normalise)
            data_x.append(x)
            data_y.append(y)
        return np.array(data_x), np.array(data_y)

    def generate_train_batch(self, seq_len, batch_size, normalise):
        '''Yield a generator of training data from filename on given list of cols split for train/test'''
        i = 0
        while i < (self.len_train - seq_len):
            x_batch = []
            y_batch = []
            for b in range(batch_size):
                if i >= (self.len_train - seq_len):
                    # stop-condition for a smaller final batch if data doesn't divide evenly
                    yield np.array(x_batch), np.array(y_batch)
                    i = 0
                x, y = self._next_window(i, seq_len, normalise)
                x_batch.append(x)
                y_batch.append(y)
                i += 1
            yield np.array(x_batch), np.array(y_batch)

    def _next_window(self, i, seq_len, normalise):
        '''Generates the next data window from the given index location i'''
        window = self.data_train[i:i+seq_len]
        window = self.normalise_windows(window, single_window=True)[0] if normalise else window
        x = window[:-1]
        y = window[-1, [0]]
        return x, y

    def normalise_windows(self, window_data, single_window=False):
        '''Normalise window with a base value of zero'''
        normalised_data = []
        window_data = [window_data] if single_window else window_data
        for window in window_data:
            normalised_window = []
            for col_i in range(window.shape[1]):
                normalised_col = [((float(p) / float(window[0, col_i])) - 1) for p in window[:, col_i]]
                normalised_window.append(normalised_col)
            normalised_window = np.array(normalised_window).T # reshape and transpose array back into original multidimensional format
            normalised_data.append(normalised_window)
        return np.array(normalised_data)

# %%
data = DataLoader(
        "infosys.csv",
        ["Close","Volume"]
    )

x, y = data.get_data(
        seq_len=20,
        normalise=True
    )

# %%
x_train = x[:-170]
x_test = x[-170:]
y_train = y[:-170]
y_test = y[-170:]

# %%
from attention import Attention
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Dense, Dropout, LSTM,Bidirectional
from numpy import newaxis

model = Sequential([
      Bidirectional(LSTM(units=100,input_shape=(None, 2), return_sequences=True)),              
      #LSTM(units=100,input_shape=(19, 2), return_sequences=True),
      Dropout(0.2),
      LSTM(units=10,return_sequences=True),
      #LSTM(units=50,return_sequences=True),
      Dropout(0.2),
      #Attention(),
      Dense(1, activation='linear')
])
model.compile(loss='mse', optimizer='adam')

model.fit(x_train, y_train, epochs=39,
              batch_size=32)
# Out:
# WARNING:tensorflow:From C:\Users\rishi\anaconda3\envs\my-conda-env\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\rishi\anaconda3\envs\my-conda-env\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\rishi\anaconda3\envs\my-conda-env\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/39
# WARNING:tensorflow:From C:\Users\rishi\anaconda3\envs\my-conda-env\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 46/46 [==============================] - 8s 26ms/step - loss: 0.0010
# Epoch 2/39
# 46/46 [==============================] - 1s 29ms/step - loss: 4.5979e-04
# Epoch 3/39
# 46/46 [==============================] - 1s 27ms/step - loss: 3.8350e-04
# Epoch 4/39
# 46/46 [==============================] - 1s 27ms/step - loss: 3.0699e-04
# Epoch 5/39
# 46/46 [==============================] - 1s 25ms/step - loss: 3.0044e-04
# Epoch 6/39
# 46/46 [==============================] - 1s 25ms/step - loss: 2.6666e-04
# Epoch 7/39
# 46/46 [==============================] - 1s 26ms/step - loss: 2.5591e-04
# Epoch 8/39
# 46/46 [==============================] - 1s 29ms/step - loss: 2.3931e-04
# Epoch 9/39
# 46/46 [==============================] - 1s 30ms/step - loss: 2.2700e-04
# Epoch 10/39
# 46/46 [==============================] - 1s 29ms/step - loss: 2.2804e-04
# Epoch 11/39
# 46/46 [==============================] - 1s 29ms/step - loss: 2.1878e-04
# Epoch 12/39
# 46/46 [==============================] - 1s 29ms/step - loss: 2.3815e-04
# Epoch 13/39
# 46/46 [==============================] - 1s 30ms/step - loss: 2.1912e-04
# Epoch 14/39
# 46/46 [==============================] - 1s 30ms/step - loss: 2.0107e-04
# Epoch 15/39
# 46/46 [==============================] - 1s 32ms/step - loss: 1.9672e-04
# Epoch 16/39
# 46/46 [==============================] - 1s 32ms/step - loss: 1.9553e-04
# Epoch 17/39
# 46/46 [==============================] - 1s 32ms/step - loss: 1.8464e-04
# Epoch 18/39
# 46/46 [==============================] - 1s 28ms/step - loss: 1.7127e-04
# Epoch 19/39
# 46/46 [==============================] - 1s 31ms/step - loss: 1.7098e-04
# Epoch 20/39
# 46/46 [==============================] - 1s 31ms/step - loss: 2.1126e-04
# Epoch 21/39
# 46/46 [==============================] - 1s 31ms/step - loss: 1.6778e-04
# Epoch 22/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.8285e-04
# Epoch 23/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.6225e-04
# Epoch 24/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.5131e-04
# Epoch 25/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.4868e-04
# Epoch 26/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.4354e-04
# Epoch 27/39
# 46/46 [==============================] - 1s 28ms/step - loss: 1.3914e-04
# Epoch 28/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.6483e-04
# Epoch 29/39
# 46/46 [==============================] - 1s 28ms/step - loss: 1.4113e-04
# Epoch 30/39
# 46/46 [==============================] - 1s 28ms/step - loss: 1.3769e-04
# Epoch 31/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.3762e-04
# Epoch 32/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.3271e-04
# Epoch 33/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.2350e-04
# Epoch 34/39
# 46/46 [==============================] - 1s 30ms/step - loss: 1.5567e-04
# Epoch 35/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.3899e-04
# Epoch 36/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.5154e-04
# Epoch 37/39
# 46/46 [==============================] - 1s 30ms/step - loss: 1.5146e-04
# Epoch 38/39
# 46/46 [==============================] - 1s 30ms/step - loss: 1.2982e-04
# Epoch 39/39
# 46/46 [==============================] - 1s 29ms/step - loss: 1.1880e-04

# %%
from attention import Attention
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Dense, Dropout, LSTM,Bidirectional
from numpy import newaxis

model = Sequential([
      #Bidirectional(LSTM(units=100,input_shape=(None, 2), return_sequences=True)),              
      LSTM(units=100,input_shape=(19, 2), return_sequences=True),
      Dropout(0.2),
      LSTM(units=10,return_sequences=True),
      #LSTM(units=50,return_sequences=True),
      Dropout(0.2),
      Attention(),
      Dense(1, activation='linear')
])
model.compile(loss='mse', optimizer='adam')

model.fit(x_train, y_train, epochs=7,
              batch_size=32)
# Out:
# Epoch 1/7
# 46/46 [==============================] - 10s 34ms/step - loss: 0.0013
# Epoch 2/7
# 46/46 [==============================] - 1s 31ms/step - loss: 6.3033e-04
# Epoch 3/7
# 46/46 [==============================] - 1s 27ms/step - loss: 4.9303e-04
# Epoch 4/7
# 46/46 [==============================] - 1s 30ms/step - loss: 3.1903e-04
# Epoch 5/7
# 46/46 [==============================] - 1s 29ms/step - loss: 2.4592e-04
# Epoch 6/7
# 46/46 [==============================] - 1s 29ms/step - loss: 2.4911e-04
# Epoch 7/7
# 46/46 [==============================] - 1s 28ms/step - loss: 2.2048e-04

# %%
def predict_point_by_point(model, data):
    #Predict each timestep given the last sequence of true data, in effect only predicting 1 step ahead each time
    predicted = model.predict(data)
    predicted = np.reshape(predicted, (predicted.size,))
    return predicted

# %%
def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of 50 steps before shifting prediction run forward by 50 steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

# %% [markdown]
# visualistion

# %%
import lstm
import time
import matplotlib.pyplot as plt

def plot_results(predicted_data, true_data):
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    plt.plot(predicted_data, label='Prediction')
    plt.legend()
    plt.show()

def plot_results_multiple(predicted_data, true_data, prediction_len):
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Prediction')
        plt.legend()
    plt.show()

# %%
predicted = predict_point_by_point(model, x)
# Out:
# 52/52 [==============================] - 2s 11ms/step

# %%
plt.rcParams["figure.figsize"] = [30,10]
plot_results(predicted, y)

# %%
model = Sequential([
      #Bidirectional(LSTM(units=100,input_shape=(None, 2), return_sequences=True)),              
      LSTM(units=100,input_shape=(19, 2), return_sequences=True),
      Dropout(0.2),
      LSTM(units=70,return_sequences=True),
      #LSTM(units=50,return_sequences=True),
      Dropout(0.2),
      Attention(),
      Dense(1, activation='linear')
])
model.compile(loss='mse', optimizer='adam')
model.fit(x_train, y_train, epochs=1,
              batch_size=6)
predictions = predict_sequences_multiple(model,x_test,12, 10)
# Out:
# 245/245 [==============================] - 14s 25ms/step - loss: 0.0010
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step

# %%
plt.rcParams["figure.figsize"] = [20,10]
plot_results_multiple(predictions, y_test,10)

# %% [markdown]
# trading stratedy with point by point

# %%
from backtesting import Strategy
from backtesting import Backtest
from backtesting.lib import crossover
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from attention import Attention

def mean(values, n):
    """
    Return simple moving average of `values`, at
    each step taking into account `n` previous values.
    """
    return pd.Series(values).rolling(n).mean()
    
class LstmPredictStrategy(Strategy):
    n1=1
    def init(self):
        # Define any required variables or parameters here
        self.seq_len = 20
        self.window_size = 19
        self.prediction_len = 1 
        ;# Changed to predict 1 point at a time
        self.model = self.build_model()
        self.x = self.I(mean, self.data.Close, self.n1)
    
    def build_model(self):
        # Define your LSTM model here
        model = Sequential([
            LSTM(units=100, input_shape=(self.window_size, 2), return_sequences=True),
            Dropout(0.2),
            LSTM(units=10, return_sequences=True),
            Dropout(0.2),
            Attention(),
            Dense(1, activation='linear')
        ])
        model.compile(loss='mse', optimizer='adam')
        return model
        
    def train_model(self):
      
        
        # Train the model
        self.model.fit(self.data.Close, epochs=7, batch_size=32, verbose=0)

    def next(self):
        # Define the logic for making trading decisions
         # Precompute the two moving averages
     
        prediction = self.predict_point_by_point(x)
        if prediction > 0:  # Assuming the prediction is the next price change
            self.buy()
        elif prediction < 0:
            self.sell()

    def predict_point_by_point(self, data):
        #Predict the next timestep given the last sequence of true data
        predicted = self.model.predict(data)
        predicted = np.reshape(predicted, (predicted.size,))
        return predicted[-1]  # Return the last prediction for the next timestep

# %%
bt = Backtest(df, LstmPredictStrategy, cash=10_000, commission=.002) 
stats = bt.run()

stats
# Out:
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 16ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 18ms/step
# 52/52 [==============================] - 1s 16ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 18ms/step
# 52/52 [==============================] - 0s 7ms/step
# 52/52 [==============================] - 1s 18ms/step
# 52/52 [==============================] - 1s 19ms/step
# 52/52 [==============================] - 1s 17ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 139871s 13ms/step
# 52/52 [==============================] - 1s 19ms/step
# 52/52 [==============================] - 2s 26ms/step
# 52/52 [==============================] - 2s 18ms/step
# 52/52 [==============================] - 2s 24ms/step
# 52/52 [==============================] - 2s 19ms/step
# 52/52 [==============================] - 1s 19ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 2s 16ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 16ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 15ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 20ms/step
# 52/52 [==============================] - 1s 14ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 15ms/step
# ...
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 8ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 13ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 0s 9ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 9ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 11ms/step
# 52/52 [==============================] - 1s 10ms/step
# 52/52 [==============================] - 1s 12ms/step
# 52/52 [==============================] - 1s 10ms/step
# Start                     2023-01-03 09:30...
# End                       2023-12-12 15:30...
# Duration                    343 days 06:00:00
# Exposure Time [%]                   99.879373
# Equity Final [$]                  9912.547332
# Equity Peak [$]                   12266.24448
# Return [%]                          -0.874527
# Buy & Hold Return [%]               -3.463447
# Return (Ann.) [%]                   -0.390796
# Volatility (Ann.) [%]                31.71368
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -23.169439
# Avg. Drawdown [%]                   -3.190105
# Max. Drawdown Duration      232 days 06:00:00
# Avg. Drawdown Duration       21 days 08:00:00
# # Trades                                   31
# Win Rate [%]                        22.580645
# Best Trade [%]                       3.270931
# Worst Trade [%]                    -19.053679
# Avg. Trade [%]                      -9.076389
# Max. Trade Duration         343 days 04:00:00
# Avg. Trade Duration         272 days 14:00:00
# Profit Factor                        0.043171
# Expectancy [%]                      -8.740043
# SQN                                 -0.175884
# _strategy                 LstmPredictStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
bt.plot()

# %% [markdown]
# Trading Strategy with multiple point

# %%
import numpy as np
import pandas as pd
from typing import Union

_Array = Union[np.ndarray, pd.Series]

class _Data:
    def __init__(self, df):
        self.df = df
        self.__arrays = {c: df[c].values for c in df.columns}
        self.__i = len(df)
        self.__cache = {}
    
    def __getitem__(self, item):
        return self.__get_array(item)
        
    def __get_array(self, key) -> _Array:
      if isinstance(key, slice):
        start, stop, step = key.start, key.stop, key.step
        if start is None:
            start = 0
        if stop is None:
            stop = len(self.__arrays)
        if step is None:
            step = 1
        return np.concatenate([self.__arrays[i] for i in range(start, stop, step)])

      if key not in self.__arrays:
        raise KeyError(f"Column '{key}' not found in data")

      arr = self.__cache.get(key)
      if arr is None:
        arr = cast(_Array, self.__arrays[key][:self.__i])
        self.__cache[key] = arr
      return arr

# %%
from backtesting import Strategy
from backtesting.lib import crossover
import pandas as pd

class LstmPredictStrategy(Strategy):
    def init(self):
        # Define any required variables or parameters here
        self.seq_len = 20
        self.window_size = 19
        self.prediction_len = 12
        self.model = self.build_model()
        self.train_model()

    def build_model(self):
        # Define your LSTM model here
        model = Sequential([
            LSTM(units=100, input_shape=(self.window_size, 2), return_sequences=True),
            Dropout(0.2),
            LSTM(units=70, return_sequences=True),
            Dropout(0.2),
            Attention(),
            Dense(1, activation='linear')
        ])
        model.compile(loss='mse', optimizer='adam')
        return model
    
    def train_model(self):
        # Train your model here
        
        x, y = self.get_data()
        x_train = x[:-170]
        x_test = x[-170:]
        y_train = y[:-170]
        y_test = y[-170:]
        self.model.fit(x_train, y_train, epochs=1, batch_size=6)

    def get_data(self):
        # Prepare your data for training here
        data_x = []
        data_y = []
        for i in range(len(self.data) - self.seq_len):
            x, y = self._next_window(i)
            data_x.append(x)
            data_y.append(y)
        return np.array(data_x), np.array(data_y)

    def _next_window(self, i):
    # Define how each window of data is processed
       # window = self.data.iloc[i:i+self.seq_len].values.tolist()
        self.data.drop(self, labels='Datetime', axis=1,inplace=True)

        window = self.data[i:i+self.seq_len].values.tolist()
        window = self.normalise_windows(window, single_window=True)[0]
        x = window[:-1]
        y = window[-1][0]  # Assuming you want the first column value as y
        return x, y




    def normalise_windows(self, window_data, single_window=False):
        # Define how data is normalised
        normalised_data = []
        window_data = [window_data] if single_window else window_data
        for window in window_data:
            normalised_window = []
            for col_i in range(window.shape[1]):
                normalised_col = [((float(p) / float(window[0, col_i])) - 1) for p in window[:, col_i]]
                normalised_window.append(normalised_col)
            normalised_window = np.array(normalised_window).T
            normalised_data.append(normalised_window)
        return np.array(normalised_data)

    def next(self):
        # Define the logic for making trading decisions
        x = self.data[-self.seq_len:]
        prediction = self.predict_sequences_multiple(x)
        if prediction[-1][-1] > 0:  # Assuming the last prediction in the sequence is the future prediction
            self.buy()
        elif prediction[-1][-1] < 0:
            self.sell()

    def predict_sequences_multiple(self, data):
        # Define how predictions are made
        prediction_seqs = []
        for i in range(int(len(data) / self.prediction_len)):
            curr_frame = data[i * self.prediction_len]
            predicted = []
            for j in range(self.prediction_len):
                predicted.append(self.model.predict(curr_frame[np.newaxis, :, :])[0, 0])
                curr_frame = curr_frame[1:]
                curr_frame = np.insert(curr_frame, [self.window_size - 1], predicted[-1], axis=0)
            prediction_seqs.append(predicted)
        return prediction_seqs

# %%
from backtesting import Backtest

bt = Backtest(df, LstmPredictStrategy, cash=10_000, commission=.002)
stats = bt.run()
stats

# %% [markdown]
# backtesting for infosys :

# %%
from backtesting import Backtest, Strategy
from backtesting.lib import crossover

from backtesting.test import SMA


class SmaCross(Strategy):
    def init(self):
        price = self.data.Close
        self.ma1 = self.I(SMA, price, 10)
        self.ma2 = self.I(SMA, price, 20)

    def next(self):
        if crossover(self.ma1, self.ma2):
            self.buy()
        elif crossover(self.ma2, self.ma1):
            self.sell()


bt = Backtest(df, SmaCross, commission=.002,
              exclusive_orders=True)
stats = bt.run()
bt.plot()
stats
